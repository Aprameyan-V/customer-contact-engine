# %%
import pandas as pd
import numpy as np
import random

# %%
cols = pd.read_csv("DataSet.csv")

# %%
random.randint(100000,999999)
# Out:
# 670753

# %%
df =pd.DataFrame(index=range(1,2000),columns=cols.columns)

# %%
df.head()
# Out:
#   cuid name curr plans talktime data  sms Broadband speed plan satisfaction  \
# 1  NaN  NaN        NaN      NaN  NaN  NaN       NaN   NaN               NaN
# 2  NaN  NaN        NaN      NaN  NaN  NaN       NaN   NaN               NaN
# 3  NaN  NaN        NaN      NaN  NaN  NaN       NaN   NaN               NaN
# 4  NaN  NaN        NaN      NaN  NaN  NaN       NaN   NaN               NaN
# 5  NaN  NaN        NaN      NaN  NaN  NaN       NaN   NaN               NaN
#
#   date of pur ph no  email Id income door no street city zipcode state area  \
# 1         NaN    NaN      NaN    NaN     NaN    NaN  NaN     NaN   NaN  NaN
# 2         NaN    NaN      NaN    NaN     NaN    NaN  NaN     NaN   NaN  NaN
# 3         NaN    NaN      NaN    NaN     NaN    NaN  NaN     NaN   NaN  NaN
# 4         NaN    NaN      NaN    NaN     NaN    NaN  NaN     NaN   NaN  NaN
# 5         NaN    NaN      NaN    NaN     NaN    NaN  NaN     NaN   NaN  NaN
#
#   contact preference
# 1                NaN
# ...

# %%
df['cuid'].fillna(random.randint(100000,999999))
# Out:
# 1       377801
# 2       377801
# 3       377801
# 4       377801
# 5       377801
#          ...
# 1995    377801
# 1996    377801
# 1997    377801
# 1998    377801
# 1999    377801
# Name: cuid, Length: 1999, dtype: int64

# %%
df['cuid'] = np.random.randint(100000, 999999, df.shape[0])

# %%
df.head()
# Out:
#      cuid name curr plans talktime data  sms Broadband speed  \
# 1  675579  NaN        NaN      NaN  NaN  NaN       NaN   NaN
# 2  943105  NaN        NaN      NaN  NaN  NaN       NaN   NaN
# 3  293369  NaN        NaN      NaN  NaN  NaN       NaN   NaN
# 4  888058  NaN        NaN      NaN  NaN  NaN       NaN   NaN
# 5  961453  NaN        NaN      NaN  NaN  NaN       NaN   NaN
#
#   plan satisfaction date of pur ph no  email Id income door no street city  \
# 1               NaN         NaN    NaN      NaN    NaN     NaN    NaN  NaN
# 2               NaN         NaN    NaN      NaN    NaN     NaN    NaN  NaN
# 3               NaN         NaN    NaN      NaN    NaN     NaN    NaN  NaN
# 4               NaN         NaN    NaN      NaN    NaN     NaN    NaN  NaN
# 5               NaN         NaN    NaN      NaN    NaN     NaN    NaN  NaN
#
#   zipcode state area contact preference
# 1     NaN   NaN  NaN                NaN
# 2     NaN   NaN  NaN                NaN
# ...

# %%
plans=["199","299","499",'699','999','1299','1499']

# %%
df['curr plans'] = np.random.choice(plans,len(df))

# %%
df['curr plans'].value_counts()
# Out:
# 299     323
# 1499    314
# 499     289
# 699     281
# 1299    271
# 199     270
# 999     251
# Name: curr plans, dtype: int64

# %%
dta=[3,5,8,12,15,20,27]

# %%
def fill (i):
    if df.loc[index,'curr plans']==plans[i]:
        df.loc[index,'data'] = dta[i]
    print("filled for",plans[i],dta[i])

for i in range(df.shape[0]):
    fill(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\APRAME~1.V\AppData\Local\Temp/ipykernel_2544/1084722186.py in <module>
#       5
#       6 for i in range(df.shape[0]):
# ----> 7     fill(i)
#
# C:\Users\APRAME~1.V\AppData\Local\Temp/ipykernel_2544/1084722186.py in fill(i)
#       1 def fill (i):
# ----> 2     if df.loc[index,'curr plans']==plans[i]:
#       3         df.loc[index,'data'] = dta[i]
#       4     print("filled for",plans[i],dta[i])
#       5
#
# NameError: name 'index' is not defined

# %%
#plans=["199","299","499",'699','999','1299','1499']

for index in df.index:
    if df.loc[index,'curr plans']=='199':
        df.loc[index,'speed'] = 0
    elif df.loc[index,'curr plans']=='299':
        df.loc[index,'speed'] = 0
    elif df.loc[index,'curr plans']=='499':
        df.loc[index,'speed'] = 0
    elif df.loc[index,'curr plans']=='699':
        df.loc[index,'speed'] = 30
    elif df.loc[index,'curr plans']=='999':
        df.loc[index,'speed'] = 50
    elif df.loc[index,'curr plans']=='1299':
        df.loc[index,'speed'] = 100
    else:
        df.loc[index,'speed'] = 150

# %%
df.head()
# Out:
#      cuid name curr plans talktime data  sms Broadband speed  \
# 1  675579  NaN       1499      NaN   27  NaN       250   150
# 2  943105  NaN        499      NaN    8  NaN         0     0
# 3  293369  NaN        499      NaN    8  NaN         0     0
# 4  888058  NaN       1299      NaN   20  NaN       150   100
# 5  961453  NaN        999      NaN   15  NaN        90    50
#
#    plan satisfaction date of pur ph no  email Id income door no street city  \
# 1                  8         NaN    NaN      NaN    NaN     NaN    NaN  NaN
# 2                  3         NaN    NaN      NaN    NaN     NaN    NaN  NaN
# 3                  7         NaN    NaN      NaN    NaN     NaN    NaN  NaN
# 4                  5         NaN    NaN      NaN    NaN     NaN    NaN  NaN
# 5                  7         NaN    NaN      NaN    NaN     NaN    NaN  NaN
#
#   zipcode state area contact preference
# 1     NaN   NaN  NaN                NaN
# 2     NaN   NaN  NaN                NaN
# ...

# %%
df['plan satisfaction'] = np.random.choice(range(1,11),len(df))

# %%
def random_dates(start, end, n=2000):

    start_u = start.value//10**9
    end_u = end.value//10**9

    return pd.to_datetime(np.random.randint(start_u, end_u, n), unit='s')

# %%
start = pd.to_datetime('2000-01-01')
end = pd.to_datetime('2022-01-01')
date =random_dates(start, end)

# %%
len(date)
# Out:
# 2000

# %%
df['date of pur']=date[1:]

# %%
type(date)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df.tail()
# Out:
#         cuid name curr plans talktime data  sms Broadband speed  \
# 1995  895197  NaN       1499      NaN   27  NaN       250   150
# 1996  261807  NaN       1299      NaN   20  NaN       150   100
# 1997  239385  NaN        499      NaN    8  NaN         0     0
# 1998  407855  NaN       1499      NaN   27  NaN       250   150
# 1999  569384  NaN        499      NaN    8  NaN         0     0
#
#       plan satisfaction         date of pur ph no  email Id income door no  \
# 1995                  8 2001-12-28 15:58:47    NaN      NaN    NaN     NaN
# 1996                  3 2017-12-12 17:46:24    NaN      NaN    NaN     NaN
# 1997                  9 2016-10-29 03:41:11    NaN      NaN    NaN     NaN
# 1998                  5 2011-12-17 18:36:49    NaN      NaN    NaN     NaN
# 1999                  1 2008-05-20 10:40:13    NaN      NaN    NaN     NaN
#
#      street city zipcode state area contact preference
# 1995    NaN  NaN     NaN   NaN  NaN                NaN
# ...

# %%
df['ph no'] = np.random.randint(7612345698, 7665432190, df.shape[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\APRAME~1.V\AppData\Local\Temp/ipykernel_2544/2157125509.py in <module>
# ----> 1 df['ph no'] = np.random.randint(7612345698, 7665432190, df.shape[0])
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randint()
#
# _bounded_integers.pyx in numpy.random._bounded_integers._rand_int32()
#
# ValueError: high is out of bounds for int32

# %%
n = 10
''.join(["{}".format(random.randint(3, 9)) for num in range(0, n)])
# Out:
# '3666368943'

# %%
ph =[]
for i in range(len(df)+1):
    n=10
    x=''.join(["{}".format(random.randint(3, 9)) for num in range(0, n)])
    ph.append(x)

# %%
type(ph)
# Out:
# list

# %%
p = pd.Series(ph)

# %%
type(p)
# Out:
# pandas.core.series.Series

# %%
df['ph no ']=p

# %%
df.head()
# Out:
#      cuid name curr plans talktime data  sms Broadband speed  \
# 1  675579  NaN       1499      NaN   27  NaN       250   150
# 2  943105  NaN        499      NaN    8  NaN         0     0
# 3  293369  NaN        499      NaN    8  NaN         0     0
# 4  888058  NaN       1299      NaN   20  NaN       150   100
# 5  961453  NaN        999      NaN   15  NaN        90    50
#
#    plan satisfaction         date of pur      ph no  email Id income door no  \
# 1                  8 2013-12-27 05:59:16  3637968574      NaN    NaN     NaN
# 2                  3 2004-06-03 14:01:48  9578737955      NaN    NaN     NaN
# 3                  7 2013-09-21 08:14:32  3595566466      NaN    NaN     NaN
# 4                  5 2015-04-16 01:19:12  5473873788      NaN    NaN     NaN
# 5                  7 2020-10-23 14:30:10  6494396657      NaN    NaN     NaN
#
#   street city zipcode state area contact preference
# 1    NaN  NaN     NaN   NaN  NaN                NaN
# ...

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
type(df['cuid'])
# Out:
# pandas.core.series.Series

# %%
df.drop("ph no",axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['cuid', 'name', 'curr plans', 'talktime', 'data', 'sms', 'Broadband',
#        'speed', 'plan satisfaction', 'date of pur', 'ph no ', 'email Id',
#        'income', 'door no', 'street', 'city', 'zipcode', 'state', 'area',
#        'contact preference'],
#       dtype='object')

# %%
df.rename({"ph no ":"ph no"},axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['cuid', 'name', 'curr_plans', 'talktime', 'data', 'sms', 'Broadband',
#        'speed', 'plan_satisfaction', 'date_of_pur', 'ph_no', 'email_Id',
#        'income', 'door_no', 'street', 'city', 'zipcode', 'state', 'area',
#        'contact_preference'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#      cuid name curr_plans talktime data  sms Broadband speed  \
# 1  675579  NaN       1499      NaN   27  NaN       250   150
# 2  943105  NaN        499      NaN    8  NaN         0     0
# 3  293369  NaN        499      NaN    8  NaN         0     0
# 4  888058  NaN       1299      NaN   20  NaN       150   100
# 5  961453  NaN        999      NaN   15  NaN        90    50
#
#    plan_satisfaction         date_of_pur       ph_no email_Id income door_no  \
# 1                  8 2013-12-27 05:59:16  3637968574      NaN    NaN     NaN
# 2                  3 2004-06-03 14:01:48  9578737955      NaN    NaN     NaN
# 3                  7 2013-09-21 08:14:32  3595566466      NaN    NaN     NaN
# 4                  5 2015-04-16 01:19:12  5473873788      NaN    NaN     NaN
# 5                  7 2020-10-23 14:30:10  6494396657      NaN    NaN     NaN
#
#   street city zipcode state area contact_preference
# 1    NaN  NaN     NaN   NaN  NaN                NaN
# ...

# %%
income=[3.5,4.6,5.5,7.5,10,15,21,0]

# %%
df['income'] = np.random.choice(income,len(df))

# %%
df.head()
# Out:
#      cuid name curr_plans talktime data  sms Broadband speed  \
# 1  675579  NaN       1499      NaN   27  NaN       250   150
# 2  943105  NaN        499      NaN    8  NaN         0     0
# 3  293369  NaN        499      NaN    8  NaN         0     0
# 4  888058  NaN       1299      NaN   20  NaN       150   100
# 5  961453  NaN        999      NaN   15  NaN        90    50
#
#    plan_satisfaction         date_of_pur       ph_no email_Id  income door_no  \
# 1                  8 2013-12-27 05:59:16  3637968574      NaN     7.5     NaN
# 2                  3 2004-06-03 14:01:48  9578737955      NaN    10.0     NaN
# 3                  7 2013-09-21 08:14:32  3595566466      NaN    15.0     NaN
# 4                  5 2015-04-16 01:19:12  5473873788      NaN    21.0     NaN
# 5                  7 2020-10-23 14:30:10  6494396657      NaN     4.6     NaN
#
#   street city zipcode state area contact_preference
# 1    NaN  NaN     NaN   NaN  NaN                NaN
# ...

# %%
pref = ['Email','WhatsApp','call']
df['contact_preference'] = np.random.choice(pref,len(df))

# %%
df.head(20)
# Out:
#       cuid name curr_plans talktime data  sms Broadband speed  \
# 1   675579  NaN       1499      NaN   27  NaN       250   150
# 2   943105  NaN        499      NaN    8  NaN         0     0
# 3   293369  NaN        499      NaN    8  NaN         0     0
# 4   888058  NaN       1299      NaN   20  NaN       150   100
# 5   961453  NaN        999      NaN   15  NaN        90    50
# 6   149783  NaN       1299      NaN   20  NaN       150   100
# 7   168433  NaN       1499      NaN   27  NaN       250   150
# 8   666132  NaN        999      NaN   15  NaN        90    50
# 9   469887  NaN        199      NaN    3  NaN         0     0
# 10  382411  NaN        199      NaN    3  NaN         0     0
# 11  605291  NaN        999      NaN   15  NaN        90    50
# 12  678389  NaN        499      NaN    8  NaN         0     0
# 13  962022  NaN        199      NaN    3  NaN         0     0
# 14  757240  NaN        699      NaN   12  NaN        50    30
# ...

# %%
df.to_csv("First_draft.csv")
