# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/onlinedeliverydata.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ##### What input do we need :
# 1. Name
# 2. Gender
# 3. Marital Status
# 4. Occupation
# 5. Monthly Income
# 6. Educational Qualifications
# 7. Family size
# 8. Store
# 9. Pin code
# 10. Contact_Medium
# 11. Phon_Number
# 12. Email_ID

# %%
#Reading the names file:

with open('Names.txt') as f:
    lines = f.readlines()

# %%
type(lines)
# Out:
# list

# %%
lines[1][:-1]
# Out:
# 'Aabharan'

# %%
len(lines)
# Out:
# 55691

# %%
import random
name=[]
for i in range(2000):
    name.append(lines[random.randint(5,len(lines))][:-1])

# %%
names=pd.Series(name)

# %%
data = names.to_frame("Name").reset_index()

# %%
data
# Out:
#       index                  Name  Gender Marital_Status  Occupation  \
# 0         0                Varuna    Male        Married     Student
# 1         1        Vaikunthanatha  Female        Married  House_wife
# 2         2                  Veda    Male        Married  House_wife
# 3         3                Kughen    Male         Single    Employee
# 4         4           Prabhavathy  Female         Single    Employee
# 5         5             Yathusara    Male        Married    Employee
# 6         6           Logeshwaran    Male         Single     Student
# 7         7               Leyonan    Male         Single    Employee
# 8         8                Devika    Male        Married     Student
# 9         9                Labdhi    Male         Single    Employee
# 10       10                 Yajus  Female         Single    Employee
# 11       11              Tharmini  Female        Married  House_wife
# 12       12             Veyashnna  Female         Single     Student
# ...

# %%
df["Gender"].value_counts()
# Out:
# Male      222
# Female    166
# Name: Gender, dtype: int64

# %%
x=["Male","Female"]

# %%
data['Gender'] = np.random.choice(x,len(data))

# %%
def create (colm):
    data[colm] = np.random.choice(x,len(data))

# %%
create("y")

# %%
data.drop("Pin code",axis=1,inplace=True)

# %% [markdown]
# ##### What input do we need :
# 1. Name
# 2. Gender
# 3. Marital Status
# 4. Occupation
# 5. Monthly Income
# 6. Educational Qualifications
# 7. Family size
# 8. Store
# 9. Pin code
# 10. Contact_Medium
# 11. Phon_Number
# 12. Email_ID

# %%
a=df["Pin code"].value_counts()

# %%
a.index
# Out:
# Int64Index([560009, 560038, 560010, 560076, 560095, 560034, 560036, 560075,
#             560043, 560029, 560001, 560024, 560080, 560066, 560003, 560096,
#             560015, 560018, 560011, 560017, 560021, 560005, 560041, 560002,
#             560008, 560027, 560085, 560004, 560092, 560006, 560023, 560042,
#             560030, 560103, 560020, 560078, 560067, 560070, 560100, 560007,
#             560093, 560048, 560012, 560014, 560068, 560046, 560025, 560022,
#             560016, 560061, 560013, 560028, 560102, 560019, 560056, 560062,
#             560060, 560055, 560045, 560049, 560086, 560064, 560032, 560091,
#             560097, 560059, 560079, 560098, 560104, 560109, 560051, 560050,
#             560073, 560047, 560033, 560026, 560072],
#            dtype='int64')

# %%
x = ["E-mail","WhatsApp"]

# %%
create("Contact_Medium")

# %%
ph =[]
for i in range(len(data)+1):
    n=10
    x=''.join(["{}".format(random.randint(3, 9)) for num in range(0, n)])
    ph.append(x)

# %%
p = pd.Series(ph)

# %%
data['Phone_Number']=p

# %%
data["Email_ID"]=data.apply(lambda x: x["Name"] + "@gmail.com" , axis=1)

# %%
data
# Out:
#       index                  Name  Gender Marital_Status  Occupation  \
# 0         0                Varuna    Male        Married     Student
# 1         1        Vaikunthanatha  Female        Married  House_wife
# 2         2                  Veda    Male        Married  House_wife
# 3         3                Kughen    Male         Single    Employee
# 4         4           Prabhavathy  Female         Single    Employee
# 5         5             Yathusara    Male        Married    Employee
# 6         6           Logeshwaran    Male         Single     Student
# 7         7               Leyonan    Male         Single    Employee
# 8         8                Devika    Male        Married     Student
# 9         9                Labdhi    Male         Single    Employee
# 10       10                 Yajus  Female         Single    Employee
# 11       11              Tharmini  Female        Married  House_wife
# 12       12             Veyashnna  Female         Single     Student
# ...

# %%
data.drop("index",axis=1,inplace=True)

# %%
data.head()
# Out:
#              Name  Gender Marital_Status  Occupation  Monthly_Income  \
# 0          Varuna    Male        Married     Student           10000
# 1  Vaikunthanatha  Female        Married  House_wife           50000
# 2            Veda    Male        Married  House_wife           10000
# 3          Kughen    Male         Single    Employee           50000
# 4     Prabhavathy  Female         Single    Employee            5000
#
#   Educational_Qualifications  Family_size Store  Pin_code Contact_Medium  \
# 0                       Ph.D            3    s5    560098         E-mail
# 1                 Uneducated            3    s4    560006       WhatsApp
# 2              Post_Graduate            5    s4    560015       WhatsApp
# 3              Post_Graduate            1    s5    560002         E-mail
# 4              Post_Graduate            6    s3    560075         E-mail
#
#   Phone_Number                  Email_ID
# 0   8599335698          Varuna@gmail.com
# ...

# %%
data.to_csv()
